# %%
import matplotlib.pyplot as plt

# %%
from astropy.io import fits
import numpy as np
from scipy.ndimage import gaussian_filter1d
from scipy.signal import medfilt

# continuum = medfilt(spec, kernel_size=301)

# Open the FITS file
with fits.open("spEigenGal-53054.fits") as hdul:
    # print(hdul.info())
    data_full = hdul[0].data  # continumm + lines data
    spec = data_full.astype(np.float64)
    data_continuum = medfilt(spec, kernel_size=301)
    # data_continumm = gaussian_filter1d(data_full, sigma=150)
    data_lines = data_full-data_continumm

# print(type(data))
print(data.shape)
# Out:
# /tmp/ipykernel_9313/2760693441.py:13: UserWarning: kernel_size exceeds volume extent: the volume will be zero-padded.
#   data_continuum = medfilt(spec, kernel_size=301)
# (4, 7012)

# %%
plt.plot(data_lines[0,:])
plt.show()

# %%
from astropy.io import fits
import numpy as np

with fits.open("spec-1678-53433-0425.fits") as hdul:
    spec = hdul[1].data

flux = spec["flux"]
wavelength = 10**spec["loglam"]
ivar = spec["ivar"]

import matplotlib.pyplot as plt

plt.plot(wavelength, flux)
plt.xlabel("Wavelength (Å)")
plt.ylabel("Flux")
plt.show()

# %%
with fits.open("spec-1678-53433-0425.fits") as hdul:
    hdul.info()
# Out:
# Filename: spec-1678-53433-0425.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     141   ()
#   1  COADD         1 BinTableHDU     26   3846R x 8C   [E, E, E, J, J, E, E, E]
#   2  SPECOBJ       1 BinTableHDU    262   1R x 126C   [6A, 4A, 16A, 23A, 16A, 8A, E, E, E, J, E, E, J, B, B, B, B, B, B, J, 22A, 19A, 19A, 22A, 19A, I, 3A, 3A, 1A, J, D, D, D, E, E, 19A, 8A, J, J, J, J, K, K, J, J, J, J, J, J, K, K, K, K, I, J, J, J, J, 5J, D, D, 6A, 21A, E, E, E, J, E, 24A, 10J, J, 10E, E, E, E, E, E, E, J, E, E, E, J, E, 5E, E, 10E, 10E, 10E, 5E, 5E, 5E, 5E, 5E, J, J, E, E, E, E, E, E, 25A, 21A, 10A, E, E, E, E, E, E, E, E, J, E, E, J, 1A, 1A, E, E, J, J, 1A, 5E, 5E]
#   3  SPZLINE       1 BinTableHDU     48   29R x 19C   [J, J, J, 13A, D, E, E, E, E, E, E, E, E, E, E, J, J, E, E]

# %%
from astropy.io import fits
import numpy as np

with fits.open("spec-1678-53433-0425.fits") as hdul:
    data = hdul[1].data
    print(hdul.info())
    # print(type(data))
    # print(type(hdul[1]))
    print(type(hdul))
    # print(hdul[1].columns)

flux = data["flux"]
wave = 10**data["loglam"]
plt.plot(wave,flux)
# Out:
# Filename: spec-1678-53433-0425.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     141   ()
#   1  COADD         1 BinTableHDU     26   3846R x 8C   ['E', 'E', 'E', 'J', 'J', 'E', 'E', 'E']
#   2  SPECOBJ       1 BinTableHDU    262   1R x 126C   [6A, 4A, 16A, 23A, 16A, 8A, E, E, E, J, E, E, J, B, B, B, B, B, B, J, 22A, 19A, 19A, 22A, 19A, I, 3A, 3A, 1A, J, D, D, D, E, E, 19A, 8A, J, J, J, J, K, K, J, J, J, J, J, J, K, K, K, K, I, J, J, J, J, 5J, D, D, 6A, 21A, E, E, E, J, E, 24A, 10J, J, 10E, E, E, E, E, E, E, J, E, E, E, J, E, 5E, E, 10E, 10E, 10E, 5E, 5E, 5E, 5E, 5E, J, J, E, E, E, E, E, E, 25A, 21A, 10A, E, E, E, E, E, E, E, E, J, E, E, J, 1A, 1A, E, E, J, J, 1A, 5E, 5E]
#   3  SPZLINE       1 BinTableHDU     48   29R x 19C   [J, J, J, 13A, D, E, E, E, E, E, E, E, E, E, E, J, J, E, E]
# None
# <class 'astropy.io.fits.hdu.hdulist.HDUList'>

# %%
from astropy.io import fits

with fits.open("spec-1678-53433-0425.fits") as hdul:
    hdul.info()

    for i in range(len(hdul)):
        print(f"\nHDU {i}: {hdul[i].name}")

        if hasattr(hdul[i], "columns"):
            print(hdul[i].columns)
# Out:
# Filename: spec-1678-53433-0425.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     141   ()
#   1  COADD         1 BinTableHDU     26   3846R x 8C   [E, E, E, J, J, E, E, E]
#   2  SPECOBJ       1 BinTableHDU    262   1R x 126C   [6A, 4A, 16A, 23A, 16A, 8A, E, E, E, J, E, E, J, B, B, B, B, B, B, J, 22A, 19A, 19A, 22A, 19A, I, 3A, 3A, 1A, J, D, D, D, E, E, 19A, 8A, J, J, J, J, K, K, J, J, J, J, J, J, K, K, K, K, I, J, J, J, J, 5J, D, D, 6A, 21A, E, E, E, J, E, 24A, 10J, J, 10E, E, E, E, E, E, E, J, E, E, E, J, E, 5E, E, 10E, 10E, 10E, 5E, 5E, 5E, 5E, 5E, J, J, E, E, E, E, E, E, 25A, 21A, 10A, E, E, E, E, E, E, E, E, J, E, E, J, 1A, 1A, E, E, J, J, 1A, 5E, 5E]
#   3  SPZLINE       1 BinTableHDU     48   29R x 19C   [J, J, J, 13A, D, E, E, E, E, E, E, E, E, E, E, J, J, E, E]
#
# HDU 0: PRIMARY
#
# HDU 1: COADD
# ColDefs(
#     name = 'flux'; format = 'E'
#     name = 'loglam'; format = 'E'
#     name = 'ivar'; format = 'E'
# ...
